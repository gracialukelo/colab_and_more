data_url = "https://sites.google.com/roche.com/site-managementmannheim/wir-sind-die-site"  # Ersetze durch die URL für die geschützten Daten

# Session-Objekt erstellen, um die Sitzung zu speichern
session = requests.Session()

# Anmeldedaten vorbereiten
login_data = {
    'username': '',  # Füge deinen Benutzernamen hier ein
    'password': ''  # Füge dein Passwort hier ein
}

# Anmeldung durchführen
login_response = session.post(login_url, data=login_data)

# Überprüfen, ob die Anmeldung erfolgreich war
if login_response.ok:
    print("Login erfolgreich")

    # Geschützte Seite abrufen
    response = session.get(data_url)
    if response.status_code == 200:
        # HTML-Inhalt parsen
        soup = BeautifulSoup(response.text, 'html.parser')

        # Entferne unerwünschte Elemente wie Skripte und Styles
        for script in soup(["script", "style"]):
            script.decompose()

        # Gesamten Text auf der Seite sammeln
        text = '\n'.join(soup.stripped_strings)

        # Frage-Antwort-Pipeline initialisieren
        reader = pipeline("question-answering", model="distilbert-base-cased-distilled-squad", device=-1)

        # Beispiel-Frage
        question = input("Wie kann ich dir helfen?:\n")

        while question.lower() != "break":
            # Frage beantworten
            q_results = reader(question=question, context=text)

            # Antwort anzeigen
            print("Answer:\n", q_results['answer'])

            # Neue Frage stellen
            question = input("Write 'break' to stop the program:\n")
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
else:
    print("Login fehlgeschlagen. Bitte überprüfe deine Anmeldedaten.")
# Out:
# Login fehlgeschlagen. Bitte überprüfe deine Anmeldedaten.

# %%
import nest_asyncio
import asyncio
from playwright.async_api import async_playwright

# Damit wir async in Jupyter/Colab verwenden können
nest_asyncio.apply()

async def fetch_page_content():
    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()

        # Webseite laden
        url = "https://www.roche.com/"
        await page.goto(url)

        # Warte, bis die Seite vollständig geladen ist
        await page.wait_for_load_state("networkidle")

        # Gesamten Textinhalt der Seite erfassen
        content = await page.content()

        # Browser schließen
        await browser.close()

        return content

# Führe die asynchrone Funktion direkt aus
content = await fetch_page_content()
print(content)
# Out:
# <!DOCTYPE html><html lang="en" class="theme--page" dir="ltr" data-cache-buster="?version=1730714864482" data-react-helmet="lang,class"><head><style type="text/css" id="bc-style-vjs" data-vjs-version="7.21.4">@charset "UTF-8";.video-js .vjs-big-play-button .vjs-icon-placeholder:before,.video-js .vjs-modal-dialog,.vjs-button>.vjs-icon-placeholder:before,.vjs-modal-dialog .vjs-modal-dialog-content{position:absolute;top:0;left:0;width:100%;height:100%}.video-js .vjs-big-play-button .vjs-icon-placeholder:before,.vjs-button>.vjs-icon-placeholder:before{text-align:center}@font-face{font-family:VideoJS;src:url(data:application/font-woff;charset=utf-8;base64,...) format("woff");font-weight:400;font-style:normal}.video-js .vjs-big-play-button .vjs-icon-placeholder:before,.video-js .vjs-play-control .vjs-icon-placeholder,.vjs-icon-play{font-family:VideoJS;font-weight:400;font-style:normal}.video-js .vjs-big-play-button .vjs-icon-placeholder:before,.video-js .vjs-play-control .vjs-icon-placehold
# ...

# %%
from transformers import pipeline
from bs4 import BeautifulSoup

# %%
html_content = content

# HTML parsen und Text extrahieren
soup = BeautifulSoup(html_content, "html.parser")
context = ""

# Füge alle <h1>, <h2> und <p>-Tags hinzu
for tag in soup.find_all(['h1', 'h2', 'p']):
    context += f"{tag.get_text()}\n"

print("Bereinigter Kontext:\n", context)
# Out:
# Bereinigter Kontext:
#  Doing now what patients need next
# In the spotlight
# Roche has established a multi-lingual global hotline (tel: +36 146 182 58; WhatsApp +36 707 177 394) and an email address (patientcare@roche.com) for patients and healthcare providers in or from Ukraine. We will do our best to provide everyone who is in need with the appropriate information and support.
# Perspectives and powerful moments that shape healthcare.
# For professionals
# This website contains information on products which is targeted to a wide range of audiences and could contain product details or information otherwise not accessible or valid in your country. Please be aware that we do not take any responsibility for accessing such information which may not comply with any legal process, regulation, registration or usage in the country of your origin.
#
#
# ...

# %%
# Frage-Antwort-Pipeline initialisieren
reader = pipeline("question-answering", model="distilbert-base-cased-distilled-squad", device=-0)

# Beispiel-Frage
question = input("Wie kann ich dir helfen?:\n")

while question.lower() != "break":
  q_results = reader(question=question, context=html_content)

        # Antwort anzeigen
  print("Answer:\n", q_results['answer'])

        # Neue Frage stellen
  question = input("Write 'break' to stop the program:\n")
# Out:
# Wie kann ich dir helfen?:
# tell me about roche
# Answer:
#  linear-gradient
# Write 'break' to stop the program:
# Our strategy
# Answer:
#  transition
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-c60b148de5be> in <cell line: 7>()
#      12
#      13         # Neue Frage stellen
# ---> 14   question = input("Write 'break' to stop the program:\n")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, logging
from huggingface_hub import login
import torch

# Logging aktivieren, um Informationen über das Laden des Modells und Fehler anzuzeigen
logging.set_verbosity_info()

# Hugging Face Login mit Token (ersetze 'your_huggingface_token_here' durch deinen tatsächlichen Token)
login("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")

# LLaMA-Modell und Tokenizer laden
model_name = "meta-llama/Llama-2-7b-chat-hf"

# Modell und Tokenizer laden
try:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")
except Exception as e:
    logging.error(f"Fehler beim Laden des Modells: {e}")
    raise e

# Kontext und Frage definieren
context = "Roche ist ein globales Gesundheitsunternehmen, das im Bereich Pharmazeutika und Diagnostik tätig ist. Es wurde 1896 gegründet und hat seinen Hauptsitz in Basel, Schweiz."
question = "Tell me about roche?"
input_text = f"Kontext: {context}\nFrage: {question}"

# Tokenisierung und Modell-Ausgabe
inputs = tokenizer(input_text, return_tensors="pt").to("cuda")
outputs = model.generate(**inputs, max_new_tokens=50)
answer = tokenizer.decode(outputs[0], skip_special_tokens=True)

print(answer)
# Out:
# Could not locate the tokenizer configuration file, will try to use the model config instead.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     303     try:
# --> 304         response.raise_for_status()
#     305     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1023         if http_error_msg:
# ...

# %%
import logging
from transformers import AutoModelForCausalLM, AutoTokenizer
from huggingface_hub import login
import torch

# Configure logging to output info and error messages
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Hugging Face Login with token
login("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")  # Replace with your token

# Load model and tokenizer
model_name = "meta-llama/Llama-2-7b-chat-hf"

try:
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")
    logger.info("Model and tokenizer loaded successfully.")
except Exception as e:
    logger.error(f"Error loading model or tokenizer: {e}")
    raise e  # Re-raise the exception after logging

# Define context and question
context = "Roche ist ein globales Gesundheitsunternehmen, das im Bereich Pharmazeutika und Diagnostik tätig ist. Es wurde 1896 gegründet und hat seinen Hauptsitz in Basel, Schweiz."
question = "Tell me about Roche?"
input_text = f"Kontext: {context}\nFrage: {question}"

# Tokenize and generate output
try:
    inputs = tokenizer(input_text, return_tensors="pt").to("cuda")
    outputs = model.generate(**inputs, max_new_tokens=50)
    answer = tokenizer.decode(outputs[0], skip_special_tokens=True)
    print(answer)
except Exception as e:
    logger.error(f"Error during model inference: {e}")
